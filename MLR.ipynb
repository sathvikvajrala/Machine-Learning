# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("ToyotaCorolla - MLR.csv")
df
# Out:
#       Price  Age_08_04     KM Fuel_Type  ...  Doors  Cylinders  Gears  Weight
# 0     13500         23  46986    Diesel  ...      3          4      5    1165
# 1     13750         23  72937    Diesel  ...      3          4      5    1165
# 2     13950         24  41711    Diesel  ...      3          4      5    1165
# 3     14950         26  48000    Diesel  ...      3          4      5    1165
# 4     13750         30  38500    Diesel  ...      3          4      5    1170
# ...     ...        ...    ...       ...  ...    ...        ...    ...     ...
# 1431   7500         69  20544    Petrol  ...      3          4      5    1025
# 1432  10845         72  19000    Petrol  ...      3          4      5    1015
# 1433   8500         71  17016    Petrol  ...      3          4      5    1015
# 1434   7250         70  16916    Petrol  ...      3          4      5    1015
# 1435   6950         76      1    Petrol  ...      5          4      5    1114
#
# [1436 rows x 11 columns]

# %%
df.head()
# Out:
#    Price  Age_08_04     KM Fuel_Type  HP  ...    cc  Doors  Cylinders  Gears  Weight
# 0  13500         23  46986    Diesel  90  ...  2000      3          4      5    1165
# 1  13750         23  72937    Diesel  90  ...  2000      3          4      5    1165
# 2  13950         24  41711    Diesel  90  ...  2000      3          4      5    1165
# 3  14950         26  48000    Diesel  90  ...  2000      3          4      5    1165
# 4  13750         30  38500    Diesel  90  ...  2000      3          4      5    1170
#
# [5 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age_08_04  1436 non-null   int64
#  2   KM         1436 non-null   int64
#  3   Fuel_Type  1436 non-null   object
#  4   HP         1436 non-null   int64
#  5   Automatic  1436 non-null   int64
#  6   cc         1436 non-null   int64
#  7   Doors      1436 non-null   int64
#  8   Cylinders  1436 non-null   int64
#  9   Gears      1436 non-null   int64
#  10  Weight     1436 non-null   int64
# dtypes: int64(10), object(1)
# memory usage: 123.5+ KB

# %%
df.describe()
# Out:
#               Price    Age_08_04  ...        Gears      Weight
# count   1436.000000  1436.000000  ...  1436.000000  1436.00000
# mean   10730.824513    55.947075  ...     5.026462  1072.45961
# std     3626.964585    18.599988  ...     0.188510    52.64112
# min     4350.000000     1.000000  ...     3.000000  1000.00000
# 25%     8450.000000    44.000000  ...     5.000000  1040.00000
# 50%     9900.000000    61.000000  ...     5.000000  1070.00000
# 75%    11950.000000    70.000000  ...     5.000000  1085.00000
# max    32500.000000    80.000000  ...     6.000000  1615.00000
#
# [8 rows x 10 columns]

# %%
df.shape
# Out:
# (1436, 11)

# %%
df.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'Fuel_Type', 'HP', 'Automatic', 'cc',
#        'Doors', 'Cylinders', 'Gears', 'Weight'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Price         int64
# Age_08_04     int64
# KM            int64
# Fuel_Type    object
# HP            int64
# Automatic     int64
# cc            int64
# Doors         int64
# Cylinders     int64
# Gears         int64
# Weight        int64
# dtype: object

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# * The relation between y and X should be high. The higher the value, the stronger the correlation
# * The relation between any two independent variables should be low
#  * if the correlation between any 2 independent variables is strong, then it is called a collinearity problem

# %%
df.drop("Fuel_Type",axis=1).corr()
# Out:
#               Price  Age_08_04        KM  ...  Cylinders     Gears    Weight
# Price      1.000000  -0.876590 -0.569960  ...        NaN  0.063104  0.581198
# Age_08_04 -0.876590   1.000000  0.505672  ...        NaN -0.005364 -0.470253
# KM        -0.569960   0.505672  1.000000  ...        NaN  0.015023 -0.028598
# HP         0.314990  -0.156622 -0.333538  ...        NaN  0.209477  0.089614
# Automatic  0.033081   0.031717 -0.081854  ...        NaN -0.098555  0.057249
# cc         0.126389  -0.098084  0.102683  ...        NaN  0.014629  0.335637
# Doors      0.185326  -0.148359 -0.036197  ...        NaN -0.160141  0.302618
# Cylinders       NaN        NaN       NaN  ...        NaN       NaN       NaN
# Gears      0.063104  -0.005364  0.015023  ...        NaN  1.000000  0.020613
# Weight     0.581198  -0.470253 -0.028598  ...        NaN  0.020613  1.000000
#
# [10 rows x 10 columns]

# %%
x=df.drop(columns="Price")
y=df["Price"]

# %% [markdown]
# we used drop because fuel_type was object for that we do correlation.

# %% [markdown]
# Train-Test Split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
x_train
# Out:
#       Age_08_04      KM Fuel_Type   HP  ...  Doors  Cylinders  Gears  Weight
# 366          35   21904    Petrol   97  ...      3          4      5    1025
# 1141         73  103121    Petrol   86  ...      5          4      5    1035
# 1337         75   63634    Petrol  110  ...      4          4      5    1035
# 139          20   23000    Petrol  110  ...      5          4      5    1130
# 271          38   48197    Petrol  110  ...      5          4      5    1075
# ...         ...     ...       ...  ...  ...    ...        ...    ...     ...
# 1393         69   49640    Petrol  110  ...      4          4      5    1035
# 1344         74   61700    Petrol  110  ...      5          4      5    1070
# 527          54   49366    Petrol   97  ...      3          4      5    1025
# 1149         74  100732    Petrol   86  ...      4          4      5    1030
# 1289         78   72090    Petrol  110  ...      5          4      5    1070
#
# [1148 rows x 10 columns]

# %%
from os.path import join
x_train_encoded=pd.get_dummies(x_train,columns=['Fuel_Type'],drop_first=True)
x_test_encoded=pd.get_dummies(x_test,columns=['Fuel_Type'],drop_first=True)

x_train_encoded,x_test_encoded=x_train_encoded.align(x_test_encoded,join='left',axis=1,fill_value=0)

# %%
x_train_encoded
# Out:
#       Age_08_04      KM   HP  ...  Weight  Fuel_Type_Diesel  Fuel_Type_Petrol
# 366          35   21904   97  ...    1025             False              True
# 1141         73  103121   86  ...    1035             False              True
# 1337         75   63634  110  ...    1035             False              True
# 139          20   23000  110  ...    1130             False              True
# 271          38   48197  110  ...    1075             False              True
# ...         ...     ...  ...  ...     ...               ...               ...
# 1393         69   49640  110  ...    1035             False              True
# 1344         74   61700  110  ...    1070             False              True
# 527          54   49366   97  ...    1025             False              True
# 1149         74  100732   86  ...    1030             False              True
# 1289         78   72090  110  ...    1070             False              True
#
# [1148 rows x 11 columns]

# %% [markdown]
# Modelling

# %% [markdown]
# * Multiple Linear Regression—Linear regression includes multiple input features. This is done by least squares method
# y = B₀ + B₁x₁ + ... Bₙxₙ
#
# Each x represents a different feature, and each feature has its own coefficient

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train_encoded,y_train)
print(model.intercept_)
print(model.coef_)
# Out:
# -8126.483082021134
# [-1.23583672e+02 -1.73719292e-02  2.71737234e+01  3.69249456e+02
#  -2.69356617e-02 -1.02486185e+01  4.54747351e-13  6.26862704e+02
#   1.84927921e+01  9.49917760e+02  1.31162806e+03]

# %%
train_prediction=model.predict(x_train_encoded)
test_prediction=model.predict(x_test_encoded)

# %%
from sklearn.metrics import mean_squared_error
train_RSME=np.sqrt(mean_squared_error(y_train,train_prediction))
test_RSME=np.sqrt(mean_squared_error(y_test,test_prediction))
print(train_RSME)
print(test_RSME)
# Out:
# 1311.233442159675
# 1429.3153492137762

# %%
print(model.score(x_train_encoded,y_train))
print(model.score(x_test_encoded,y_test))
# Out:
# 0.8650926368721761
# 0.8607794569185007

# %% [markdown]
# Lasso Regression

# %%
from sklearn.linear_model import Lasso
Lasso_model=Lasso()
Lasso_model.fit(x_train_encoded,y_train)
print(Lasso_model.intercept_)
print(Lasso_model.coef_)
# Out:
# -7939.978545675176
# [-1.23441495e+02 -1.74595756e-02  2.67935600e+01  3.43993752e+02
#  -2.25012741e-02 -1.09447116e+01  0.00000000e+00  6.04529641e+02
#   1.85918142e+01  7.77486590e+02  1.16600179e+03]

# %%
lasso_train_prediction=Lasso_model.predict(x_train_encoded)
lasso_test_prediction=Lasso_model.predict(x_test_encoded)

# %%
from sklearn.metrics import mean_squared_error
lasso_train_RSME=np.sqrt(mean_squared_error(lasso_train_prediction,y_train))
lasso_test_RSME=np.sqrt(mean_squared_error(lasso_test_prediction,y_test))
print(lasso_train_RSME)
print(lasso_test_RSME)
print(Lasso_model.score(x_train_encoded,y_train))
print(Lasso_model.score(x_test_encoded,y_test))
# Out:
# 1311.372761028243
# 1427.5309577514417
# 0.8650639674696392
# 0.8611268524451684

# %% [markdown]
# Ridge Regression

# %%
from sklearn.linear_model import Ridge
ridge_model=Ridge()
ridge_model.fit(x_train_encoded,y_train)
print(ridge_model.intercept_)
print(ridge_model.coef_)
# Out:
# -7979.664910168785
# [-1.23486080e+02 -1.74570078e-02  2.69111684e+01  3.59201364e+02
#  -2.42077955e-02 -1.10593587e+01  0.00000000e+00  6.17772034e+02
#   1.85433242e+01  8.06439223e+02  1.18265994e+03]

# %%
ridge_train_prediction=ridge_model.predict(x_train_encoded)
ridge_test_prediction=ridge_model.predict(x_test_encoded)

# %%
from sklearn.metrics import mean_squared_error
ridge_train_RSME=np.sqrt(mean_squared_error(ridge_train_prediction,y_train))
ridge_test_RSME=np.sqrt(mean_squared_error(ridge_test_prediction,y_test))
print(ridge_train_RSME)
print(ridge_test_RSME)
# Out:
# 1311.3256023934377
# 1427.9592669342076

# %%
print(ridge_model.score(x_train_encoded,y_train))
print(ridge_model.score(x_test_encoded,y_test))
# Out:
# 0.8650736722383385
# 0.8610435063472776

# %% [markdown]
# #### What is Normalization & Standardization and how is it helpful?
# Normalization is a data preprocessing technique used to rescale the values of numerical features so that they fall within a specific range, typically [0, 1]. It's especially important in machine learning and data analysis to ensure that all features contribute equally to the model’s learning
#
# ### Why Normalize?
# Eliminates Bias: Features with larger ranges won't dominate those with smaller ranges.
#
# Improves Model Performance: Algorithms like k-NN, SVM, and neural networks are sensitive to feature scales.
#
# Speeds Up Convergence: Gradient descent converges faster when features are on a similar scale.
#
# #### Standardization
# ##### What is Standardization?
# Standardization is a data preprocessing technique that transforms features to have:
#
# Mean = 0
#
# Standard deviation = 1
#
# This process is also called Z-score normalization.
#
# ### Why is Standardization Useful?
#
# 1. **Equal Feature Scaling**
#    Like normalization, it makes sure features with different units or scales (e.g., income vs age) contribute equally to the model.
#
# 2. **Works Well with Normally Distributed Data**
#    Some algorithms assume or perform better when the input features follow a normal (Gaussian) distribution. Standardization helps meet this assumption.
#
# 3. **Improves Model Performance**
#    Algorithms that are sensitive to feature distribution benefit from standardization:
#
#    | Algorithm             | Needs Standardization? |
#    |-----------------------|------------------------|
#    | k-NN                  |    Yes                 |
#    | SVM                   |    Yes                 |
#    | Logistic Regression   |    Yes                 |
#    | Linear Regression     |    Yes                 |
#    | Neural Networks       |    Yes                 |
#    | Decision Trees/Random Forests |  Not necessary |
#
# 4. **Faster Gradient Descent**
#    In models like linear regression or neural networks, standardization helps gradient descent converge faster by reducing zigzagging.
